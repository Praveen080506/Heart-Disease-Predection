# %%
import keras

# %%
from keras.models import Sequential
models = Sequential()

# %%
from keras.layers import Dense

# %%
import pandas as pd
dt = pd.read_csv('/content/heart.csv')
dt.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
dt.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.103240 -0.071966  0.271121  0.219823  0.121243
# sex      -0.103240  1.000000 -0.041119 -0.078974 -0.198258  0.027200
# cp       -0.071966 -0.041119  1.000000  0.038177 -0.081641  0.079294
# trestbps  0.271121 -0.078974  0.038177  1.000000  0.127977  0.181767
# chol      0.219823 -0.198258 -0.081641  0.127977  1.000000  0.026917
# fbs       0.121243  0.027200  0.079294  0.181767  0.026917  1.000000
# restecg  -0.132696 -0.055117  0.043581 -0.123794 -0.147410 -0.104051
# thalach  -0.390227 -0.049365  0.306839 -0.039264 -0.021772 -0.008866
# exang     0.088163  0.139157 -0.401513  0.061197  0.067382  0.049261
# oldpeak   0.208137  0.084687 -0.174733  0.187434  0.064880  0.010859
# slope    -0.169105 -0.026666  0.131633 -0.120445 -0.014248 -0.061902
# ca        0.271551  0.111729 -0.176206  0.104554  0.074259  0.137156
# thal      0.072297  0.198424 -0.163341  0.059276  0.100244 -0.042177
# ...

# %%
print(dt.columns)

columns_to_drop = ['chol', 'fbs']
existing_columns_to_drop = [col for col in columns_to_drop if col in dt.columns]

if existing_columns_to_drop:
    dt = dt.drop(existing_columns_to_drop, axis=1)
    print("Columns dropped successfully.")
else:
    print("Columns 'chol' and 'fbs' not found in the DataFrame.")
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'restecg', 'thalach', 'exang',
#        'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')
# Columns 'chol' and 'fbs' not found in the DataFrame.

# %%
dt.tail(1)
# Out:
#       age  sex  cp  trestbps  restecg  thalach  exang  oldpeak  slope  ca  \
# 1024   54    1   0       120        1      113      0      1.4      1   1
#
#       thal  target
# 1024     3       0

# %%
x = dt.iloc[:,0:11]
y = dt['target']

# %%
x
# Out:
#       age  sex  cp  trestbps  restecg  thalach  exang  oldpeak  slope  ca  \
# 0      52    1   0       125        1      168      0      1.0      2   2
# 1      53    1   0       140        0      155      1      3.1      0   0
# 2      70    1   0       145        1      125      1      2.6      0   0
# 3      61    1   0       148        1      161      0      0.0      2   1
# 4      62    0   0       138        1      106      0      1.9      1   3
# ...   ...  ...  ..       ...      ...      ...    ...      ...    ...  ..
# 1020   59    1   1       140        1      164      1      0.0      2   0
# 1021   60    1   0       125        0      141      1      2.8      1   1
# 1022   47    1   0       110        0      118      1      1.0      1   1
# 1023   50    0   0       110        0      159      0      0.0      2   0
# 1024   54    1   0       120        1      113      0      1.4      1   1
#
#       thal
# 0        3
# 1        3
# 2        3
# 3        3
# 4        2
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25)

# %%
print(x.shape,y.shape,x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (1025, 11) (1025,) (768, 11) (257, 11) (768,) (257,)

# %%
models.add(Dense(units=11,activation='relu'))

# %%
models.add(Dense(units=5,activation='relu'))

# %%
obj.add(Dense(units=1,activation='sigmoid'))

# %%
models.add(Dense(units=11,activation='relu'))
models.add(Dense(units=5,activation='relu'))
models.add(Dense(units=1,activation='sigmoid'))
models.build(input_shape=(None,11))

# %%
models.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 11)             │           132 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │            60 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             6 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 11)             │            22 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 5)              │            60 │
# ...

# %%
models.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
models.fit(x_train,y_train,epochs=100,batch_size=8,steps_per_epoch=x_train.shape[0]//8)
# Out:
# Epoch 1/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8318 - loss: 0.3678
# Epoch 2/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8552 - loss: 0.3497
# Epoch 3/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8555 - loss: 0.3349
# Epoch 4/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8171 - loss: 0.4074
# Epoch 5/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8595 - loss: 0.3704
# Epoch 6/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8493 - loss: 0.3525
# Epoch 7/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8548 - loss: 0.3590
# Epoch 8/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8441 - loss: 0.3751
# Epoch 9/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8280 - loss: 0.3997
# Epoch 10/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8591 - loss: 0.3545
# Epoch 11/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8549 - loss: 0.3681
# Epoch 12/100
# ...

# %%
y_pred = models.predict(x_test)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
y_pred = (y_pred > 0.5).astype(int)

# %%
from sklearn.metrics import accuracy_score  #Evaluation
accuracy_score(y_test,y_pred)
# Out:
# 0.7976653696498055

# %%
models.save('heart.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
x_train
# Out:
#      age  sex  cp  trestbps  restecg  thalach  exang  oldpeak  slope  ca  thal
# 740   44    1   2       140        0      180      0      0.0      2   0     2
# 241   67    1   2       152        0      150      0      0.8      1   0     3
# 290   52    1   2       138        1      169      0      0.0      2   4     2
# 905   64    1   0       120        0       96      1      2.2      0   1     2
# 632   45    0   1       130        0      175      0      0.6      1   0     2
# ..   ...  ...  ..       ...      ...      ...    ...      ...    ...  ..   ...
# 626   58    1   2       132        0      173      0      3.2      2   2     3
# 291   58    1   0       128        0      130      1      3.0      1   2     3
# 449   52    1   0       112        1      160      0      0.0      2   1     2
# 808   51    1   2        94        1      154      1      0.0      2   1     3
# 60    29    1   1       130        0      202      0      0.0      2   0     2
#
# [768 rows x 11 columns]

# %%
x_train.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'restecg', 'thalach', 'exang',
#        'oldpeak', 'slope', 'ca', 'thal'],
#       dtype='object')
